# %%
import numpy as np

# %%
import numpy as np

# %%
import pandas as pd

# %%
dispo_alim = pd.read_csv('dispo_alimentaire.csv')
dispo_alim
# Out:
#                Zone                Produit   Origine  Aliments pour animaux  \
# 0       Afghanistan       Abats Comestible   animale                    NaN
# 1       Afghanistan        Agrumes, Autres  vegetale                    NaN
# 2       Afghanistan  Aliments pour enfants  vegetale                    NaN
# 3       Afghanistan                 Ananas  vegetale                    NaN
# 4       Afghanistan                Bananes  vegetale                    NaN
# ...             ...                    ...       ...                    ...
# 15600  Îles Salomon       Viande de Suides   animale                    NaN
# 15601  Îles Salomon    Viande de Volailles   animale                    NaN
# 15602  Îles Salomon          Viande, Autre   animale                    NaN
# 15603  Îles Salomon                    Vin  vegetale                    NaN
# 15604  Îles Salomon         Épices, Autres  vegetale                    NaN
#
# ...

# %%
sous_nutrition = pd.read_csv('sous_nutrition.csv')
sous_nutrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Zone    1218 non-null   object
#  1   Année   1218 non-null   object
#  2   Valeur  624 non-null    object
# dtypes: object(3)
# memory usage: 28.7+ KB

# %%
population = pd.read_csv('population.csv')

# %%
aide_alim = pd.read_csv('aide_alimentaire.csv')

# %%
sous_nutrition.dtypes
# Out:
# Zone      object
# Année     object
# Valeur    object
# dtype: object

# %%
sous_nutrition.loc[sous_nutrition['Valeur'] == '<0.1', 'Valeur'] = 0

# %%
sous_nutrition['Valeur'].astype(float)
# Out:
# 0        8.6
# 1        8.8
# 2        8.9
# 3        9.7
# 4       10.5
#         ...
# 1213     NaN
# 1214     NaN
# 1215     NaN
# 1216     NaN
# 1217     NaN
# Name: Valeur, Length: 1218, dtype: float64

# %%
sous_nutrition.rename(columns={'Zone':'Pays'}, inplace = True)

# %%
sous_nutrition.head()
# Out:
#           Pays      Année Valeur
# 0  Afghanistan  2012-2014    8.6
# 1  Afghanistan  2013-2015    8.8
# 2  Afghanistan  2014-2016    8.9
# 3  Afghanistan  2015-2017    9.7
# 4  Afghanistan  2016-2018   10.5

# %%
len(sous_nutrition['Pays'].unique())
# Out:
# 203

# %%
sous_nutrition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1218 entries, 0 to 1217
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Pays    1218 non-null   object
#  1   Année   1218 non-null   object
#  2   Valeur  624 non-null    object
# dtypes: object(3)
# memory usage: 28.7+ KB

# %%
sous_nutrition.shape
# Out:
# (1218, 3)

# %%
sous_nutrition.loc[sous_nutrition['Valeur'].isnull(), :]
# Out:
#            Pays      Année Valeur
# 24    Allemagne  2012-2014    NaN
# 25    Allemagne  2013-2015    NaN
# 26    Allemagne  2014-2016    NaN
# 27    Allemagne  2015-2017    NaN
# 28    Allemagne  2016-2018    NaN
# ...         ...        ...    ...
# 1213   Zimbabwe  2013-2015    NaN
# 1214   Zimbabwe  2014-2016    NaN
# 1215   Zimbabwe  2015-2017    NaN
# 1216   Zimbabwe  2016-2018    NaN
# 1217   Zimbabwe  2017-2019    NaN
#
# [594 rows x 3 columns]

# %%
mask = (~sous_nutrition['Valeur'].isnull()) & (sous_nutrition.Année == '2016-2018')

# %%
sous_nutrition.loc[mask]
# Out:
#                                         Pays      Année Valeur
# 4                                Afghanistan  2016-2018   10.5
# 10                            Afrique du Sud  2016-2018    3.1
# 16                                   Albanie  2016-2018    0.1
# 22                                   Algérie  2016-2018    1.3
# 40                                    Angola  2016-2018    5.8
# ...                                      ...        ...    ...
# 1156                            Turkménistan  2016-2018    0.2
# 1174                                 Ukraine  2016-2018    1.5
# 1186                                 Vanuatu  2016-2018      0
# 1192  Venezuela (République bolivarienne du)  2016-2018      8
# 1198                                Viet Nam  2016-2018    6.5
#
# [104 rows x 3 columns]

# %%
population.rename(columns={'Zone':'Pays'}, inplace = True)

# %%
population_2017 = population.loc[population['Année'] == 2017, :]
population_2017.head()
# Out:
#               Pays  Année     Valeur
# 4      Afghanistan   2017  36296.113
# 10  Afrique du Sud   2017  57009.756
# 16         Albanie   2017   2884.169
# 22         Algérie   2017  41389.189
# 28       Allemagne   2017  82658.409

# %%
pd.merge(mask, population_2017, on='Pays', how='outer')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17544\270485460.py in <module>
# ----> 1 pd.merge(mask, population_2017, on='Pays', how='outer')
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     105     validate: str | None = None,
#     106 ) -> DataFrame:
# --> 107     op = _MergeOperation(
#     108         left,
#     109         right,
#
# ~\anaconda3\lib\site-packages\pandas\core\reshape\merge.py in __init__(self, left, right, how, on, left_on, right_on, axis, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     626         validate: str | None = None,
#     627     ):
# --> 628         _left = _validate_operand(left)
#     629         _right = _validate_operand(right)
# ...
